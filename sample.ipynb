# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import json
import unicodedata
import warnings
from basketball_reference_scraper.teams import get_roster
import pandas as pd
import numpy as np

# Suppress all warnings
warnings.filterwarnings("ignore")

# Team map with team IDs
nba_teams_map = {
    "Atlanta": "team1",
    "Boston": "team2",
    "Brooklyn": "team3",
    "Charlotte": "team4",
    "Chicago": "team5",
    "Cleveland": "team6",
    "Dallas": "team7",
    "Denver" : "team8",
    "Detroit": "team9",
    "Golden State": "team10",
    "Houston": "team11",
    "Indiana": "team12",
    "LA": "team13",  # Assuming LA refers to Los Angeles Clippers (team13)
    "Los Angeles": "team14",
    "Memphis": "team15",
    "Miami": "team16",
    "Milwaukee": "team17",
    "Minnesota": "team18",
    "New Orleans": "team19",
    "New York": "team20",
    "Oklahoma City": "team21",
    "Orlando": "team22",
    "Philadelphia": "team23",
    "Phoenix": "team24",
    "Portland": "team25",
    "Sacramento": "team26",
    "San Antonio": "team27",
    "Toronto": "team28",
    "Utah": "team29",
    "Washington": "team30"    
}

# Team abbreviations
team_abbreviations = {
    "ATL": "Atlanta",
    "BOS": "Boston",
    "BRK": "Brooklyn",
    "CHO": "Charlotte",
    "CHI": "Chicago",
    "CLE": "Cleveland",
    "DAL": "Dallas",
    "DEN": "Denver",
    "DET": "Detroit",
    "GSW": "Golden State",
    "HOU": "Houston",
    "IND": "Indiana",
    "LAC": "LA",
    "LAL": "Los Angeles",
    "MEM": "Memphis",
    "MIA": "Miami",
    "MIL": "Milwaukee",
    "MIN": "Minnesota",
    "NOP": "New Orleans",
    "NYK": "New York",
    "OKC": "Oklahoma City",
    "ORL": "Orlando",
    "PHI": "Philadelphia",
    "PHO": "Phoenix",
    "POR": "Portland",
    "SAC": "Sacramento",
    "SAS": "San Antonio",
    "TOR": "Toronto",
    "UTA": "Utah",
    "WAS": "Washington"
}

# Function to normalize names and remove accents
def normalize_name(name):
    return unicodedata.normalize('NFKD', name).encode('ASCII', 'ignore').decode('ASCII')

# Function to process each team's roster and save it as a JSON file
def create_roster_json(team_abbreviation, team_name):
    # Fetch roster data
    roster_df = get_roster(team_abbreviation, '2024')
    
    # Check if the DataFrame was returned correctly
    if roster_df is None or roster_df.empty:
        print(f"Failed to retrieve roster for {team_name} ({team_abbreviation}). Skipping...")
        return
    
    # Replace NaN values with None
    roster_df = roster_df.replace({np.nan: None})
    
    # Ensure birthdate is in string format (YYYY-MM-DD)
    if 'BIRTH_DATE' in roster_df.columns:
        roster_df['BIRTH_DATE'] = roster_df['BIRTH_DATE'].apply(lambda x: x.strftime('%Y-%m-%d') if pd.notnull(x) else None)
    
    # Create list to hold player data
    players = []
    team_id_number = int(nba_teams_map[team_name].replace('team', ''))
    
    # Process each player
    for idx, row in roster_df.iterrows():
        player_id = f"player{team_id_number * 100 + (idx + 1)}"
        player = {
            "_id": player_id,
            "name": normalize_name(row['PLAYER']),
            "position": row['POS'],
            "team_id": nba_teams_map[team_name],
            "birthdate": row['BIRTH_DATE'],
            "height": row['HEIGHT'],  # Keep height in original format
            "weight": f"{row['WEIGHT']} lbs" if row['WEIGHT'] else None,
            "college": row['COLLEGE'],
            "starter": False,  # You can modify this based on your criteria
            "number": row['NUMBER'],
            "nationality": row['NATIONALITY'],
            "experience": row['EXPERIENCE']
        }
        players.append(player)
    
    # Save to JSON file
    filename = f"{team_abbreviation.lower()}_roster.json"
    with open(filename, 'w') as f:
        json.dump(players, f, indent=2)
    print(f"Saved {filename}")

# Loop through all teams and create their roster JSON files
for team_abbreviation, team_name in team_abbreviations.items():
    create_roster_json(team_abbreviation, team_name)
# Out:
# Saved atl_roster.json
# Saved bos_roster.json
# Saved brk_roster.json
# Saved cho_roster.json
# Saved chi_roster.json
# Saved cle_roster.json
# Saved dal_roster.json
# Saved den_roster.json
# Saved det_roster.json
# Saved gsw_roster.json
# Saved hou_roster.json
# Saved ind_roster.json
# Saved lac_roster.json
# Saved lal_roster.json
# Saved mem_roster.json
# Saved mia_roster.json
# Saved mil_roster.json
# Saved min_roster.json
# Saved nop_roster.json
# Saved nyk_roster.json
# Saved okc_roster.json
# Saved orl_roster.json
# Saved phi_roster.json
# Saved pho_roster.json
# Saved por_roster.json
# Saved sac_roster.json
# Saved sas_roster.json
# Saved tor_roster.json
# Saved uta_roster.json
# Saved was_roster.json

# %%
import json
import logging
from basketball_reference_scraper.players import get_game_logs
import pandas as pd
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# Setup logging
logging.basicConfig(filename='player_stats_processing.log', 
                    level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Function to load a team's roster
def load_team_roster(team_abbreviation):
    filename = f"{team_abbreviation.lower()}_roster.json"
    with open(filename, 'r') as file:
        return json.load(file)

# Function to load a team's match data
def load_team_matches(team_number):
    filename = f"team{team_number}_matches.json"
    with open(filename, 'r') as file:
        return json.load(file)

# Function to find the match ID based on the date
def find_match_id(matches, game_date):
    for match in matches:
        try:
            if match['match_date'] == game_date:
                return match['_id']  # Use '_id' directly
        except KeyError as e:
            logging.error(f"KeyError: Missing key '{e.args[0]}' in match data for game on date {game_date}")
            continue
    return None

# Function to create statistics.json for a team
def create_team_statistics_json(team_abbreviation, team_number):
    roster = load_team_roster(team_abbreviation)
    matches = load_team_matches(team_number)
    statistics = []
    stat_id_counter = team_number * 1000  # Start stat counter based on team number

    for player in roster:
        player_id = player['_id']
        player_name = player['name']
        
        logging.info(f"Processing player: {player_name}")
        try:
            # Get player game logs
            game_logs = get_game_logs(player_name, '2024', playoffs=False)
            logging.info(f"Successfully retrieved game logs for {player_name}.")
        except Exception as e:
            logging.error(f"Could not retrieve game logs for {player_name}: {e}")
            continue  # Continue with the next player if there is an issue
        
        # Process each game
        for _, game in game_logs.iterrows():
            # Check if minutes played (mp) is greater than 0
            if pd.to_numeric(game['MP'].replace(':', '.'), errors='coerce') > 0:
                game_date = game['DATE'].strftime('%Y-%m-%d')
                match_id = find_match_id(matches, game_date)
                
                if match_id:
                    # Create the statistics entry
                    stat_entry = {
                        "_id": f"stat{stat_id_counter}",
                        "match_id": match_id,
                        "player_id": player_id,
                        "age": game['AGE'],
                        "gs": game['GS'],
                        "mp": game['MP'],
                        "fg": game['FG'],
                        "fga": game['FGA'],
                        "drb": game['DRB'],
                        "trb": game['TRB'],
                        "ast": game['AST'],
                        "stl": game['STL'],
                        "blk": game['BLK'],
                        "tov": game['TOV'],
                        "pf": game['PF'],
                        "pts": game['PTS'],
                        "plus_minus": game['+/-'],
                    }
                    statistics.append(stat_entry)
                    stat_id_counter += 1
    
    # Save statistics to JSON
    output_filename = f"team{team_number}_statistics.json"
    with open(output_filename, 'w') as outfile:
        json.dump(statistics, outfile, indent=2)
    logging.info(f"Saved statistics for {team_abbreviation} to {output_filename}.")
    print(f"Statistics saved for {team_abbreviation}")

# Updated team abbreviations
team_abbreviations = {
    "ATL": "Atlanta",
    "BOS": "Boston",
    "BRK": "Brooklyn",
    "CHO": "Charlotte",
    "CHI": "Chicago",
    "CLE": "Cleveland",
    "DAL": "Dallas",
    "DEN": "Denver",
    "DET": "Detroit",
    "GSW": "Golden State",
    "HOU": "Houston",
    "IND": "Indiana",
    "LAC": "LA",
    "LAL": "Los Angeles",
    "MEM": "Memphis",
    "MIA": "Miami",
    "MIL": "Milwaukee",
    "MIN": "Minnesota",
    "NOP": "New Orleans",
    "NYK": "New York",
    "OKC": "Oklahoma City",
    "ORL": "Orlando",
    "PHI": "Philadelphia",
    "PHO": "Phoenix",
    "POR": "Portland",
    "SAC": "Sacramento",
    "SAS": "San Antonio",
    "TOR": "Toronto",
    "UTA": "Utah",
    "WAS": "Washington"
}

nba_teams_map = {
    "Atlanta": "team1",
    "Boston": "team2",
    "Brooklyn": "team3",
    "Charlotte": "team4",
    "Chicago": "team5",
    "Cleveland": "team6",
    "Dallas": "team7",
    "Denver" : "team8",
    "Detroit": "team9",
    "Golden State": "team10",
    "Houston": "team11",
    "Indiana": "team12",
    "LA": "team13",
    "Los Angeles": "team14",
    "Memphis": "team15",
    "Miami": "team16",
    "Milwaukee": "team17",
    "Minnesota": "team18",
    "New Orleans": "team19",
    "New York": "team20",
    "Oklahoma City": "team21",
    "Orlando": "team22",
    "Philadelphia": "team23",
    "Phoenix": "team24",
    "Portland": "team25",
    "Sacramento": "team26",
    "San Antonio": "team27",
    "Toronto": "team28",
    "Utah": "team29",
    "Washington": "team30"    
}

for team_abbreviation, team_name in team_abbreviations.items():
    team_number = int(nba_teams_map[team_name].replace("team", ""))
    create_team_statistics_json(team_abbreviation, team_number)
# Out:
# You searched for "Saddiq Bey"
# 1 result found.
# Saddiq Bey
# Results for Saddiq Bey:
#
# You searched for "Bogdan Bogdanovic"
# 2 results found.
# You searched for "Kobe Bufkin"
# 0 results found.
# You searched for "Clint Capela"
# 3 results found.
# You searched for "Bruno Fernando"
# 1 result found.
# Bruno Fernando
# Results for Bruno Fernando:
#
# You searched for "Trent Forrest"
# 1 result found.
# Trent Forrest
# Results for Trent Forrest:
#
# You searched for "AJ Griffin"
# 3 results found.
# You searched for "Mouhamed Gueye"
# 1 result found.
# Mouhamed Sene
# Results for Mouhamed Sene:
#
# You searched for "De'Andre Hunter"
# 1 result found.
# De'Andre Hunter
# Results for De'Andre Hunter:
#
# You searched for "Jalen Johnson"
# 38 results found.
# You searched for "Vit Krejci"
# 0 results found.
# You searched for "Seth Lundy"
# 1 result found.
# Seth Curry
# Results for Seth Curry:
#
# You searched for "Garrison Mathews"
# 1 result found.
# Garrison Mathews
# Results for Garrison Mathews:
#
# You searched for "Wesley Matthews"
# 2 results found.
# You searched for "Patty Mills"
# 3 results found.
# You searched for "Dejounte Murray"
# 1 result found.
# Dejounte Murray
# Results for Dejounte Murray:
#
# You searched for "Onyeka Okongwu"
# 1 result found.
# Onyeka Okongwu
# Results for Onyeka Okongwu:
#
# You searched for "Dylan Windler"
# 1 result found.
# Dylan Windler
# Results for Dylan Windler:
#
# You searched for "Trae Young"
# 8 results found.
# Statistics saved for ATL
# You searched for "Dalano Banton"
# 0 results found.
# You searched for "Oshae Brissett"
# 1 result found.
# Oshae Brissett
# Results for Oshae Brissett:
#
# You searched for "Jaylen Brown"
# 10 results found.
# You searched for "JD Davison"
# 16 results found.
# You searched for "Sam Hauser"
# 4 results found.
# You searched for "Jrue Holiday"
# 2 results found.
# You searched for "Al Horford"
# 5 results found.
# You searched for "Luke Kornet"
# 1 result found.
# Luke Kornet
# Results for Luke Kornet:
#
# You searched for "Svi Mykhailiuk"
# 0 results found.
# You searched for "Drew Peterson"
# 3 results found.
# You searched for "Kristaps Porzingis"
# 1 result found.
# Kristaps Porzingis
# Results for Kristaps Porzingis:
#
# You searched for "Payton Pritchard"
# 1 result found.
# Payton Pritchard
# Results for Payton Pritchard:
#
# You searched for "Neemias Queta"
# 0 results found.
# You searched for "Jaden Springer"
# 1 result found.
# Jim Springer
# Results for Jim Springer:
#
# You searched for "Lamar Stevens"
# 4 results found.
# You searched for "Jayson Tatum"
# 1 result found.
# Jayson Tatum
# Results for Jayson Tatum:
#
# You searched for "Xavier Tillman Sr."
# 1 result found.
# Xavier Tillman
# Results for Xavier Tillman:
#
# You searched for "Jordan Walsh"
# 7 results found.
# You searched for "Derrick White"
# 6 results found.
# Statistics saved for BOS
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Mikal Bridges"
# 3 results found.
# You searched for "Armoni Brooks"
# 2 results found.
# You searched for "Nic Claxton"
# 2 results found.
# You searched for "Noah Clowney"
# 0 results found.
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Dorian Finney-Smith"
# 1 result found.
# Dorian Finney-Smith
# Results for Dorian Finney-Smith:
#
# You searched for "Harry Giles"
# 15 results found.
# You searched for "Jacob Gilyard"
# 0 results found.
# You searched for "Cameron Johnson"
# 7 results found.
# You searched for "Keon Johnson"
# 36 results found.
# You searched for "Dariq Whitehead"
# 0 results found.
# You searched for "Royce O'Neale"
# 1 result found.
# Royce O'Neale
# Results for Royce O'Neale:
#
# You searched for "Dennis Schroder"
# 1 result found.
# Dennis Schroder
# Results for Dennis Schroder:
#
# You searched for "Day'Ron Sharpe"
# 0 results found.
# You searched for "Ben Simmons"
# 4 results found.
# You searched for "Dennis Smith Jr."
# 1 result found.
# Dennis Smith
# Results for Dennis Smith:
#
# You searched for "Cam Thomas"
# 12 results found.
# You searched for "Lonnie Walker IV"
# 1 result found.
# Lonnie Walker
# Results for Lonnie Walker:
#
# You searched for "Trendon Watford"
# 0 results found.
# You searched for "Jalen Wilson"
# 7 results found.
# Statistics saved for BRK
# You searched for "Amari Bailey"
# 4 results found.
# You searched for "LaMelo Ball"
# 3 results found.
# You searched for "Davis Bertans"
# 3 results found.
# You searched for "Leaky Black"
# 0 results found.
# You searched for "Marques Bolden"
# 1 result found.
# Marques Bolden
# Results for Marques Bolden:
#
# You searched for "James Bouknight"
# 0 results found.
# You searched for "Miles Bridges"
# 3 results found.
# You searched for "Seth Curry"
# 4 results found.
# You searched for "Gordon Hayward"
# 1 result found.
# Gordon Hayward
# Results for Gordon Hayward:
#
# You searched for "Theo Maledon"
# 1 result found.
# Theo Maledon
# Results for Theo Maledon:
#
# You searched for "Tre Mann"
# 3 results found.
# You searched for "Cody Martin"
# 9 results found.
# You searched for "Bryce McGowens"
# 0 results found.
# You searched for "Nathan Mensah"
# 0 results found.
# You searched for "Vasilije Micic"
# 0 results found.
# You searched for "Brandon Miller"
# 3 results found.
# You searched for "Frank Ntilikina"
# 1 result found.
# Frank Ntilikina
# Results for Frank Ntilikina:
#
# You searched for "Aleksej Pokusevski"
# 1 result found.
# Aleksej Pokusevski
# Results for Aleksej Pokusevski:
#
# You searched for "Nick Richards"
# 1 result found.
# Nick Richards
# Results for Nick Richards:
#
# You searched for "Terry Rozier"
# 9 results found.
# You searched for "Ish Smith"
# 34 results found.
# You searched for "Nick Smith Jr."
# 0 results found.
# You searched for "JT Thor"
# 1 result found.
# Rod Thorn
# Results for Rod Thorn:
#
# You searched for "P.J. Washington"
# 5 results found.
# You searched for "Grant Williams"
# 34 results found.
# You searched for "Mark Williams"
# 47 results found.
# Statistics saved for CHO
# You searched for "Onuralp Bitim"
# 0 results found.
# You searched for "Jevon Carter"
# 5 results found.
# You searched for "Alex Caruso"
# 6 results found.
# You searched for "Torrey Craig"
# 1 result found.
# Torrey Craig
# Results for Torrey Craig:
#
# You searched for "DeMar DeRozan"
# 1 result found.
# DeMar DeRozan
# Results for DeMar DeRozan:
#
# You searched for "Ayo Dosunmu"
# 0 results found.
# You searched for "Henri Drell"
# 0 results found.
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Andrew Funk"
# 5 results found.
# You searched for "Javonte Green"
# 2 results found.
# You searched for "Zach LaVine"
# 3 results found.
# You searched for "Julian Phillips"
# 0 results found.
# You searched for "Adama Sanogo"
# 0 results found.
# You searched for "Terry Taylor"
# 9 results found.
# You searched for "Dalen Terry"
# 4 results found.
# You searched for "Nikola Vucevic"
# 2 results found.
# You searched for "Coby White"
# 13 results found.
# You searched for "Patrick Williams"
# 4 results found.
# Statistics saved for CHI
# You searched for "Jarrett Allen"
# 2 results found.
# You searched for "Emoni Bates"
# 1 result found.
# Desmond Bane
# Results for Desmond Bane:
#
# You searched for "Darius Garland"
# 3 results found.
# You searched for "Ty Jerome"
# 3 results found.
# You searched for "Damian Jones"
# 14 results found.
# You searched for "Caris LeVert"
# 2 results found.
# You searched for "Sam Merrill"
# 4 results found.
# You searched for "Donovan Mitchell"
# 1 result found.
# Donovan Mitchell
# Results for Donovan Mitchell:
#
# You searched for "Evan Mobley"
# 3 results found.
# You searched for "Isaiah Mobley"
# 3 results found.
# You searched for "Marcus Morris"
# 5 results found.
# You searched for "Pete Nance"
# 5 results found.
# You searched for "Georges Niang"
# 4 results found.
# You searched for "Isaac Okoro"
# 2 results found.
# You searched for "Craig Porter Jr."
# 0 results found.
# You searched for "Max Strus"
# 3 results found.
# You searched for "Tristan Thompson"
# 1 result found.
# Tristan Thompson
# Results for Tristan Thompson:
#
# You searched for "Dean Wade"
# 8 results found.
# Statistics saved for CLE
# You searched for "Greg Brown III"
# 0 results found.
# You searched for "Seth Curry"
# 4 results found.
# You searched for "Dexter Dennis"
# 0 results found.
# You searched for "Luka Doncic"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Alex Fudge"
# 1 result found.
# Alex Len
# Results for Alex Len:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Josh Green"
# 14 results found.
# You searched for "Tim Hardaway Jr."
# 2 results found.
# You searched for "Jaden Hardy"
# 6 results found.
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Kyrie Irving"
# 2 results found.
# You searched for "Derrick Jones Jr."
# 1 result found.
# Derrick Jones
# Results for Derrick Jones:
#
# You searched for "Maxi Kleber"
# 1 result found.
# Maxi Kleber
# Results for Maxi Kleber:
#
# You searched for "A.J. Lawson"
# 6 results found.
# You searched for "Dereck Lively II"
# 0 results found.
# You searched for "Markieff Morris"
# 1 result found.
# Markieff Morris
# Results for Markieff Morris:
#
# You searched for "Dwight Powell"
# 3 results found.
# You searched for "Olivier-Maxence Prosper"
# 0 results found.
# You searched for "P.J. Washington"
# 5 results found.
# You searched for "Brandon Williams"
# 7 results found.
# You searched for "Grant Williams"
# 34 results found.
# Statistics saved for DAL
# You searched for "Christian Braun"
# 0 results found.
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Collin Gillespie"
# 0 results found.
# You searched for "Aaron Gordon"
# 6 results found.
# You searched for "Justin Holiday"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Jay Huff"
# 1 result found.
# Ray Kuka
# Results for Ray Kuka:
#
# You searched for "Reggie Jackson"
# 6 results found.
# You searched for "Nikola Jokic"
# 3 results found.
# You searched for "DeAndre Jordan"
# 2 results found.
# You searched for "Braxton Key"
# 1 result found.
# Brandon Roy
# Results for Brandon Roy:
#
# You searched for "Jamal Murray"
# 3 results found.
# You searched for "Zeke Nnaji"
# 1 result found.
# Zeke Nnaji
# Results for Zeke Nnaji:
#
# You searched for "Jalen Pickett"
# 0 results found.
# You searched for "Michael Porter Jr."
# 1 result found.
# Michael Porter
# Results for Michael Porter:
#
# You searched for "Julian Strawther"
# 0 results found.
# You searched for "Hunter Tyson"
# 0 results found.
# You searched for "Peyton Watson"
# 0 results found.
# Statistics saved for DEN
# You searched for "Marvin Bagley III"
# 1 result found.
# Marvin Bagley
# Results for Marvin Bagley:
#
# You searched for "Buddy Boeheim"
# 0 results found.
# You searched for "Bojan Bogdanovic"
# 2 results found.
# You searched for "Troy Brown Jr."
# 1 result found.
# Troy Brown
# Results for Troy Brown:
#
# You searched for "Alec Burks"
# 3 results found.
# You searched for "Malcolm Cazalon"
# 0 results found.
# You searched for "Cade Cunningham"
# 3 results found.
# You searched for "Jalen Duren"
# 3 results found.
# You searched for "Tosan Evbuomwan"
# 0 results found.
# You searched for "Malachi Flynn"
# 1 result found.
# Malachi Flynn
# Results for Malachi Flynn:
#
# You searched for "Simone Fontecchio"
# 0 results found.
# You searched for "Evan Fournier"
# 2 results found.
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Taj Gibson"
# 5 results found.
# You searched for "Quentin Grimes"
# 0 results found.
# You searched for "Joe Harris"
# 20 results found.
# You searched for "Killian Hayes"
# 2 results found.
# You searched for "Jaden Ivey"
# 1 result found.
# Jalen Rose
# Results for Jalen Rose:
#
# You searched for "Kevin Knox"
# 5 results found.
# You searched for "Isaiah Livers"
# 2 results found.
# You searched for "Chimezie Metu"
# 1 result found.
# Chimezie Metu
# Results for Chimezie Metu:
#
# You searched for "Shake Milton"
# 1 result found.
# Shake Milton
# Results for Shake Milton:
#
# You searched for "Monte Morris"
# 2 results found.
# You searched for "Mike Muscala"
# 2 results found.
# You searched for "Jaylen Nowell"
# 3 results found.
# You searched for "Jared Rhoden"
# 1 result found.
# Jared Reiner
# Results for Jared Reiner:
#
# You searched for "Marcus Sasser"
# 3 results found.
# You searched for "Isaiah Stewart"
# 1 result found.
# Isaiah Stewart
# Results for Isaiah Stewart:
#
# You searched for "Ausar Thompson"
# 3 results found.
# You searched for "Stanley Umude"
# 1 result found.
# Stanley Brundy
# Results for Stanley Brundy:
#
# You searched for "James Wiseman"
# 2 results found.
# Statistics saved for DET
# You searched for "Stephen Curry"
# 3 results found.
# You searched for "Usman Garuba"
# 0 results found.
# You searched for "Draymond Green"
# 2 results found.
# You searched for "Trayce Jackson-Davis"
# 0 results found.
# You searched for "Cory Joseph"
# 4 results found.
# You searched for "Jonathan Kuminga"
# 0 results found.
# You searched for "Kevon Looney"
# 5 results found.
# You searched for "Moses Moody"
# 3 results found.
# You searched for "Chris Paul"
# 15 results found.
# You searched for "Gary Payton II"
# 2 results found.
# You searched for "Brandin Podziemski"
# 0 results found.
# You searched for "Lester Quinones"
# 0 results found.
# You searched for "Jerome Robinson"
# 5 results found.
# You searched for "Gui Santos"
# 0 results found.
# You searched for "Dario Saric"
# 2 results found.
# You searched for "Pat Spencer"
# 0 results found.
# You searched for "Klay Thompson"
# 7 results found.
# You searched for "Andrew Wiggins"
# 2 results found.
# Statistics saved for GSW
# You searched for "Dillon Brooks"
# 2 results found.
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Tari Eason"
# 7 results found.
# You searched for "Jalen Green"
# 17 results found.
# You searched for "Jeff Green"
# 21 results found.
# You searched for "Nate Hinton"
# 4 results found.
# You searched for "Aaron Holiday"
# 2 results found.
# You searched for "Jock Landale"
# 0 results found.
# You searched for "Boban Marjanovic"
# 1 result found.
# Boban Marjanovic
# Results for Boban Marjanovic:
#
# You searched for "Jermaine Samuels"
# 0 results found.
# You searched for "Alperen Sengun"
# 0 results found.
# You searched for "Jabari Smith Jr."
# 1 result found.
# Jabari Smith
# Results for Jabari Smith:
#
# You searched for "Jae'Sean Tate"
# 0 results found.
# You searched for "Amen Thompson"
# 9 results found.
# You searched for "Fred VanVleet"
# 1 result found.
# Fred VanVleet
# Results for Fred VanVleet:
#
# You searched for "Cam Whitmore"
# 0 results found.
# You searched for "Jeenathan Williams"
# 1 result found.
# Johnathan Williams
# Results for Johnathan Williams:
#
# Statistics saved for HOU
# You searched for "Bruce Brown"
# 16 results found.
# You searched for "Kendall Brown"
# 2 results found.
# You searched for "Tyrese Haliburton"
# 1 result found.
# Tyrese Haliburton
# Results for Tyrese Haliburton:
#
# You searched for "Buddy Hield"
# 1 result found.
# Buddy Hield
# Results for Buddy Hield:
#
# You searched for "Isaiah Jackson"
# 3 results found.
# You searched for "Quenton Jackson"
# 1 result found.
# Justin Jackson
# Results for Justin Jackson:
#
# You searched for "James Johnson"
# 32 results found.
# You searched for "Bennedict Mathurin"
# 0 results found.
# You searched for "T.J. McConnell"
# 1 result found.
# T.J. McConnell
# Results for T.J. McConnell:
#
# You searched for "Doug McDermott"
# 2 results found.
# You searched for "Andrew Nembhard"
# 0 results found.
# You searched for "Aaron Nesmith"
# 2 results found.
# You searched for "Jordan Nwora"
# 6 results found.
# You searched for "Ben Sheppard"
# 2 results found.
# You searched for "Pascal Siakam"
# 1 result found.
# Pascal Siakam
# Results for Pascal Siakam:
#
# You searched for "Jalen Smith"
# 33 results found.
# You searched for "Daniel Theis"
# 4 results found.
# You searched for "Obi Toppin"
# 1 result found.
# Obi Toppin
# Results for Obi Toppin:
#
# You searched for "Oscar Tshiebwe"
# 0 results found.
# You searched for "Myles Turner"
# 3 results found.
# You searched for "Jarace Walker"
# 4 results found.
# You searched for "Isaiah Wong"
# 4 results found.
# Statistics saved for IND
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Brandon Boston Jr."
# 0 results found.
# You searched for "Kobe Brown"
# 22 results found.
# You searched for "Amir Coffey"
# 1 result found.
# Amir Coffey
# Results for Amir Coffey:
#
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Moussa Diabate"
# 0 results found.
# You searched for "Paul George"
# 12 results found.
# You searched for "James Harden"
# 11 results found.
# You searched for "Bones Hyland"
# 0 results found.
# You searched for "Kawhi Leonard"
# 2 results found.
# You searched for "Terance Mann"
# 1 result found.
# Terance Mann
# Results for Terance Mann:
#
# You searched for "KJ Martin"
# 9 results found.
# You searched for "Jordan Miller"
# 8 results found.
# You searched for "Xavier Moon"
# 0 results found.
# You searched for "Mason Plumlee"
# 2 results found.
# You searched for "Norman Powell"
# 1 result found.
# Norman Powell
# Results for Norman Powell:
#
# You searched for "Joshua Primo"
# 0 results found.
# You searched for "Daniel Theis"
# 4 results found.
# You searched for "P.J. Tucker"
# 5 results found.
# You searched for "Russell Westbrook"
# 1 result found.
# Russell Westbrook
# Results for Russell Westbrook:
#
# You searched for "Ivica Zubac"
# 1 result found.
# Ivica Zubac
# Results for Ivica Zubac:
#
# Statistics saved for LAC
# You searched for "Colin Castleton"
# 0 results found.
# You searched for "Max Christie"
# 1 result found.
# Doug Christie
# Results for Doug Christie:
#
# You searched for "Anthony Davis"
# 9 results found.
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Alex Fudge"
# 1 result found.
# Alex Len
# Results for Alex Len:
#
# You searched for "Harry Giles"
# 15 results found.
# You searched for "Rui Hachimura"
# 1 result found.
# Rui Hachimura
# Results for Rui Hachimura:
#
# You searched for "Jaxson Hayes"
# 3 results found.
# You searched for "D'Moi Hodge"
# 0 results found.
# You searched for "Jalen Hood-Schifino"
# 0 results found.
# You searched for "LeBron James"
# 5 results found.
# You searched for "Maxwell Lewis"
# 0 results found.
# You searched for "Skylar Mays"
# 1 result found.
# Skylar Mays
# Results for Skylar Mays:
#
# You searched for "Taurean Prince"
# 3 results found.
# You searched for "Austin Reaves"
# 4 results found.
# You searched for "Cam Reddish"
# 1 result found.
# Cam Reddish
# Results for Cam Reddish:
#
# You searched for "D'Angelo Russell"
# 1 result found.
# D'Angelo Russell
# Results for D'Angelo Russell:
#
# You searched for "Jarred Vanderbilt"
# 1 result found.
# Jarred Vanderbilt
# Results for Jarred Vanderbilt:
#
# You searched for "Gabe Vincent"
# 3 results found.
# You searched for "Dylan Windler"
# 1 result found.
# Dylan Windler
# Results for Dylan Windler:
#
# You searched for "Christian Wood"
# 1 result found.
# Christian Wood
# Results for Christian Wood:
#
# Statistics saved for LAL
# You searched for "Santi Aldama"
# 0 results found.
# You searched for "Timmy Allen"
# 7 results found.
# You searched for "Desmond Bane"
# 2 results found.
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Brandon Clarke"
# 1 result found.
# Brandon Clarke
# Results for Brandon Clarke:
#
# You searched for "Tosan Evbuomwan"
# 0 results found.
# You searched for "Wenyen Gabriel"
# 1 result found.
# Wenyen Gabriel
# Results for Wenyen Gabriel:
#
# You searched for "Jacob Gilyard"
# 0 results found.
# You searched for "Jordan Goodwin"
# 1 result found.
# Jordan Bowden
# Results for Jordan Bowden:
#
# You searched for "Shaquille Harrison"
# 1 result found.
# Shaquille Harrison
# Results for Shaquille Harrison:
#
# You searched for "Matthew Hurt"
# 1 result found.
# Matthew Aitch
# Results for Matthew Aitch:
#
# You searched for "GG Jackson II"
# 1 result found.
# Reggie Jackson
# Results for Reggie Jackson:
#
# You searched for "Jaren Jackson Jr."
# 2 results found.
# You searched for "DeJon Jarreau"
# 0 results found.
# You searched for "Trey Jemison"
# 1 result found.
# Trey Johnson
# Results for Trey Johnson:
#
# You searched for "Luke Kennard"
# 1 result found.
# Luke Kennard
# Results for Luke Kennard:
#
# You searched for "John Konchar"
# 8 results found.
# You searched for "Jake LaRavia"
# 1 result found.
# Jake Layman
# Results for Jake Layman:
#
# You searched for "Kenneth Lofton Jr."
# 0 results found.
# You searched for "Ja Morant"
# 7 results found.
# You searched for "Jaylen Nowell"
# 3 results found.
# You searched for "Maozinha Pereira"
# 0 results found.
# You searched for "Scotty Pippen Jr."
# 0 results found.
# You searched for "David Roddy"
# 5 results found.
# You searched for "Derrick Rose"
# 9 results found.
# You searched for "Zavier Simpson"
# 1 result found.
# Zavier Simpson
# Results for Zavier Simpson:
#
# You searched for "Marcus Smart"
# 4 results found.
# You searched for "Lamar Stevens"
# 4 results found.
# You searched for "Xavier Tillman Sr."
# 1 result found.
# Xavier Tillman
# Results for Xavier Tillman:
#
# You searched for "Yuta Watanabe"
# 1 result found.
# Yuta Watanabe
# Results for Yuta Watanabe:
#
# You searched for "Jack White"
# 18 results found.
# You searched for "Vince Williams Jr."
# 0 results found.
# You searched for "Ziaire Williams"
# 7 results found.
# Statistics saved for MEM
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Thomas Bryant"
# 2 results found.
# You searched for "Jimmy Butler"
# 6 results found.
# You searched for "Jamal Cain"
# 0 results found.
# You searched for "R.J. Hampton"
# 3 results found.
# You searched for "Tyler Herro"
# 4 results found.
# You searched for "Haywood Highsmith"
# 1 result found.
# Haywood Highsmith
# Results for Haywood Highsmith:
#
# You searched for "Jaime Jaquez Jr."
# 0 results found.
# You searched for "Nikola Jovic"
# 4 results found.
# You searched for "Kevin Love"
# 15 results found.
# You searched for "Kyle Lowry"
# 4 results found.
# You searched for "Caleb Martin"
# 9 results found.
# You searched for "Patty Mills"
# 3 results found.
# You searched for "Josh Richardson"
# 4 results found.
# You searched for "Duncan Robinson"
# 4 results found.
# You searched for "Orlando Robinson"
# 1 result found.
# Orlando Johnson
# Results for Orlando Johnson:
#
# You searched for "Terry Rozier"
# 9 results found.
# You searched for "Dru Smith"
# 38 results found.
# You searched for "Cole Swider"
# 0 results found.
# You searched for "Alondes Williams"
# 1 result found.
# Alan Williams
# Results for Alan Williams:
#
# You searched for "Delon Wright"
# 4 results found.
# Statistics saved for MIA
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# You searched for "Thanasis Antetokounmpo"
# 2 results found.
# You searched for "Malik Beasley"
# 3 results found.
# You searched for "MarJon Beauchamp"
# 0 results found.
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Marques Bolden"
# 1 result found.
# Marques Bolden
# Results for Marques Bolden:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Jae Crowder"
# 4 results found.
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "A.J. Green"
# 14 results found.
# You searched for "Andre Jackson Jr."
# 0 results found.
# You searched for "Damian Lillard"
# 1 result found.
# Damian Lillard
# Results for Damian Lillard:
#
# You searched for "Chris Livingston"
# 2 results found.
# You searched for "Brook Lopez"
# 4 results found.
# You searched for "Robin Lopez"
# 4 results found.
# You searched for "Khris Middleton"
# 2 results found.
# You searched for "Cameron Payne"
# 2 results found.
# You searched for "Bobby Portis"
# 7 results found.
# You searched for "Ryan Rollins"
# 6 results found.
# You searched for "TyTy Washington Jr."
# 0 results found.
# You searched for "Lindell Wigginton"
# 0 results found.
# Statistics saved for MIL
# You searched for "Nickeil Alexander-Walker"
# 1 result found.
# Nickeil Alexander-Walker
# Results for Nickeil Alexander-Walker:
#
# You searched for "Kyle Anderson"
# 16 results found.
# You searched for "Troy Brown Jr."
# 1 result found.
# Troy Brown
# Results for Troy Brown:
#
# You searched for "Mike Conley"
# 17 results found.
# You searched for "Anthony Edwards"
# 3 results found.
# You searched for "Luka Garza"
# 0 results found.
# You searched for "Rudy Gobert"
# 2 results found.
# You searched for "Justin Jackson"
# 8 results found.
# You searched for "Jaden McDaniels"
# 4 results found.
# You searched for "Jordan McLaughlin"
# 1 result found.
# Jordan McLaughlin
# Results for Jordan McLaughlin:
#
# You searched for "Leonard Miller"
# 1 result found.
# Leonard Taylor
# Results for Leonard Taylor:
#
# You searched for "Shake Milton"
# 1 result found.
# Shake Milton
# Results for Shake Milton:
#
# You searched for "Josh Minott"
# 2 results found.
# You searched for "Wendell Moore Jr."
# 0 results found.
# You searched for "Monte Morris"
# 2 results found.
# You searched for "Daishen Nix"
# 0 results found.
# You searched for "Naz Reid"
# 8 results found.
# You searched for "Karl-Anthony Towns"
# 1 result found.
# Karl-Anthony Towns
# Results for Karl-Anthony Towns:
#
# You searched for "T.J. Warren"
# 5 results found.
# Statistics saved for MIN
# You searched for "Jose Alvarado"
# 0 results found.
# You searched for "Izaiah Brockington"
# 0 results found.
# You searched for "Jalen Crutcher"
# 0 results found.
# You searched for "Dyson Daniels"
# 2 results found.
# You searched for "Kaiser Gates"
# 0 results found.
# You searched for "Jordan Hawkins"
# 0 results found.
# You searched for "Brandon Ingram"
# 4 results found.
# You searched for "Herbert Jones"
# 1 result found.
# Perry Jones
# Results for Perry Jones:
#
# You searched for "Kira Lewis Jr."
# 1 result found.
# Kira Lewis
# Results for Kira Lewis:
#
# You searched for "E.J. Liddell"
# 0 results found.
# You searched for "Naji Marshall"
# 3 results found.
# You searched for "CJ McCollum"
# 2 results found.
# You searched for "Trey Murphy III"
# 0 results found.
# You searched for "Larry Nance Jr."
# 2 results found.
# You searched for "Jeremiah Robinson-Earl"
# 0 results found.
# You searched for "Matt Ryan"
# 3 results found.
# You searched for "Dereon Seabron"
# 0 results found.
# You searched for "Jonas Valanciunas"
# 1 result found.
# Jonas Valanciunas
# Results for Jonas Valanciunas:
#
# You searched for "Zion Williamson"
# 5 results found.
# You searched for "Cody Zeller"
# 8 results found.
# Statistics saved for NOP
# You searched for "Precious Achiuwa"
# 1 result found.
# Precious Achiuwa
# Results for Precious Achiuwa:
#
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Ryan Arcidiacono"
# 1 result found.
# Ryan Arcidiacono
# Results for Ryan Arcidiacono:
#
# You searched for "RJ Barrett"
# 7 results found.
# You searched for "Bojan Bogdanovic"
# 2 results found.
# You searched for "Charlie Brown Jr."
# 1 result found.
# Charlie Brown
# Results for Charlie Brown:
#
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Alec Burks"
# 3 results found.
# You searched for "Mamadi Diakite"
# 1 result found.
# Mamadi Diakite
# Results for Mamadi Diakite:
#
# You searched for "Donte DiVincenzo"
# 1 result found.
# Donte DiVincenzo
# Results for Donte DiVincenzo:
#
# You searched for "Malachi Flynn"
# 1 result found.
# Malachi Flynn
# Results for Malachi Flynn:
#
# You searched for "Evan Fournier"
# 2 results found.
# You searched for "Taj Gibson"
# 5 results found.
# You searched for "Quentin Grimes"
# 0 results found.
# You searched for "Josh Hart"
# 9 results found.
# You searched for "Isaiah Hartenstein"
# 1 result found.
# Isaiah Hartenstein
# Results for Isaiah Hartenstein:
#
# You searched for "DaQuan Jeffries"
# 1 result found.
# DaQuan Jeffries
# Results for DaQuan Jeffries:
#
# You searched for "Miles McBride"
# 2 results found.
# You searched for "Shake Milton"
# 1 result found.
# Shake Milton
# Results for Shake Milton:
#
# You searched for "Immanuel Quickley"
# 1 result found.
# Immanuel Quickley
# Results for Immanuel Quickley:
#
# You searched for "Julius Randle"
# 3 results found.
# You searched for "Mitchell Robinson"
# 1 result found.
# Mitchell Robinson
# Results for Mitchell Robinson:
#
# You searched for "Jericho Sims"
# 0 results found.
# You searched for "Dmytro Skapintsev"
# 0 results found.
# You searched for "Jacob Toppin"
# 1 result found.
# Obi Toppin
# Results for Obi Toppin:
#
# You searched for "Dylan Windler"
# 1 result found.
# Dylan Windler
# Results for Dylan Windler:
#
# Statistics saved for NYK
# You searched for "Davis Bertans"
# 3 results found.
# You searched for "Bismack Biyombo"
# 1 result found.
# Bismack Biyombo
# Results for Bismack Biyombo:
#
# You searched for "Ousmane Dieng"
# 0 results found.
# You searched for "Luguentz Dort"
# 1 result found.
# Luguentz Dort
# Results for Luguentz Dort:
#
# You searched for "Adam Flagler"
# 0 results found.
# You searched for "Josh Giddey"
# 3 results found.
# You searched for "Shai Gilgeous-Alexander"
# 1 result found.
# Shai Gilgeous-Alexander
# Results for Shai Gilgeous-Alexander:
#
# You searched for "Gordon Hayward"
# 1 result found.
# Gordon Hayward
# Results for Gordon Hayward:
#
# You searched for "Chet Holmgren"
# 0 results found.
# You searched for "Isaiah Joe"
# 3 results found.
# You searched for "Keyontae Johnson"
# 0 results found.
# You searched for "Tre Mann"
# 3 results found.
# You searched for "Vasilije Micic"
# 0 results found.
# You searched for "Mike Muscala"
# 2 results found.
# You searched for "Aleksej Pokusevski"
# 1 result found.
# Aleksej Pokusevski
# Results for Aleksej Pokusevski:
#
# You searched for "Olivier Sarr"
# 0 results found.
# You searched for "Cason Wallace"
# 3 results found.
# You searched for "Lindy Waters III"
# 0 results found.
# You searched for "Aaron Wiggins"
# 5 results found.
# You searched for "Jalen Williams"
# 36 results found.
# You searched for "Jaylin Williams"
# 17 results found.
# You searched for "Kenrich Williams"
# 6 results found.
# Statistics saved for OKC
# You searched for "Cole Anthony"
# 3 results found.
# You searched for "Paolo Banchero"
# 0 results found.
# You searched for "Goga Bitadze"
# 1 result found.
# Goga Bitadze
# Results for Goga Bitadze:
#
# You searched for "Anthony Black"
# 4 results found.
# You searched for "Wendell Carter Jr."
# 1 result found.
# Wendell Carter
# Results for Wendell Carter:
#
# You searched for "Markelle Fultz"
# 1 result found.
# Markelle Fultz
# Results for Markelle Fultz:
#
# You searched for "Gary Harris"
# 14 results found.
# You searched for "Kevon Harris"
# 8 results found.
# You searched for "Caleb Houstan"
# 0 results found.
# You searched for "Jett Howard"
# 5 results found.
# You searched for "Joe Ingles"
# 7 results found.
# You searched for "Jonathan Isaac"
# 2 results found.
# You searched for "Chuma Okeke"
# 1 result found.
# Chuma Okeke
# Results for Chuma Okeke:
#
# You searched for "Trevelin Queen"
# 1 result found.
# Trevelin Queen
# Results for Trevelin Queen:
#
# You searched for "Admiral Schofield"
# 1 result found.
# Admiral Schofield
# Results for Admiral Schofield:
#
# You searched for "Jalen Suggs"
# 3 results found.
# You searched for "Franz Wagner"
# 2 results found.
# You searched for "Moritz Wagner"
# 2 results found.
# Statistics saved for ORL
# You searched for "Mo Bamba"
# 2 results found.
# You searched for "Nicolas Batum"
# 1 result found.
# Nicolas Batum
# Results for Nicolas Batum:
#
# You searched for "Darius Bazley"
# 3 results found.
# You searched for "Patrick Beverley"
# 1 result found.
# Patrick Beverley
# Results for Patrick Beverley:
#
# You searched for "Ricky Council IV"
# 0 results found.
# You searched for "Robert Covington"
# 1 result found.
# Robert Covington
# Results for Robert Covington:
#
# You searched for "Jeff Dowtin"
# 3 results found.
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "Danny Green"
# 20 results found.
# You searched for "Tobias Harris"
# 6 results found.
# You searched for "Buddy Hield"
# 1 result found.
# Buddy Hield
# Results for Buddy Hield:
#
# You searched for "Danuel House Jr."
# 1 result found.
# Danuel House
# Results for Danuel House:
#
# You searched for "Furkan Korkmaz"
# 1 result found.
# Furkan Korkmaz
# Results for Furkan Korkmaz:
#
# You searched for "Kenneth Lofton Jr."
# 0 results found.
# You searched for "Kyle Lowry"
# 4 results found.
# You searched for "KJ Martin"
# 9 results found.
# You searched for "Tyrese Maxey"
# 1 result found.
# Tyrese Maxey
# Results for Tyrese Maxey:
#
# You searched for "De'Anthony Melton"
# 1 result found.
# De'Anthony Melton
# Results for De'Anthony Melton:
#
# You searched for "Marcus Morris"
# 5 results found.
# You searched for "Kelly Oubre Jr."
# 1 result found.
# Kelly Oubre
# Results for Kelly Oubre:
#
# You searched for "Cameron Payne"
# 2 results found.
# You searched for "Filip Petrusev"
# 0 results found.
# You searched for "Paul Reed"
# 16 results found.
# You searched for "Javonte Smart"
# 0 results found.
# You searched for "Terquavion Smith"
# 0 results found.
# You searched for "Jaden Springer"
# 1 result found.
# Jim Springer
# Results for Jim Springer:
#
# You searched for "P.J. Tucker"
# 5 results found.
# You searched for "D.J. Wilson"
# 7 results found.
# Statistics saved for PHI
# You searched for "Grayson Allen"
# 2 results found.
# You searched for "Udoka Azubuike"
# 1 result found.
# Udoka Azubuike
# Results for Udoka Azubuike:
#
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Bol Bol"
# 11 results found.
# You searched for "Devin Booker"
# 11 results found.
# You searched for "Kevin Durant"
# 5 results found.
# You searched for "Drew Eubanks"
# 1 result found.
# Drew Eubanks
# Results for Drew Eubanks:
#
# You searched for "Jordan Goodwin"
# 1 result found.
# Jordan Bowden
# Results for Jordan Bowden:
#
# You searched for "Eric Gordon"
# 12 results found.
# You searched for "Saben Lee"
# 8 results found.
# You searched for "Nassir Little"
# 1 result found.
# Nassir Little
# Results for Nassir Little:
#
# You searched for "Theo Maledon"
# 1 result found.
# Theo Maledon
# Results for Theo Maledon:
#
# You searched for "Chimezie Metu"
# 1 result found.
# Chimezie Metu
# Results for Chimezie Metu:
#
# You searched for "Jusuf Nurkic"
# 1 result found.
# Jusuf Nurkic
# Results for Jusuf Nurkic:
#
# You searched for "Royce O'Neale"
# 1 result found.
# Royce O'Neale
# Results for Royce O'Neale:
#
# You searched for "Josh Okogie"
# 4 results found.
# You searched for "David Roddy"
# 5 results found.
# You searched for "Isaiah Thomas"
# 5 results found.
# You searched for "Ish Wainright"
# 0 results found.
# You searched for "Yuta Watanabe"
# 1 result found.
# Yuta Watanabe
# Results for Yuta Watanabe:
#
# You searched for "Thaddeus Young"
# 1 result found.
# Thaddeus Young
# Results for Thaddeus Young:
#
# Statistics saved for PHO
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Ibou Badji"
# 0 results found.
# You searched for "Dalano Banton"
# 0 results found.
# You searched for "Jamaree Bouyea"
# 0 results found.
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Moses Brown"
# 17 results found.
# You searched for "Toumani Camara"
# 0 results found.
# You searched for "Jerami Grant"
# 4 results found.
# You searched for "Ashton Hagans"
# 1 result found.
# Ashton Hagans
# Results for Ashton Hagans:
#
# You searched for "Scoot Henderson"
# 1 result found.
# Tom Henderson
# Results for Tom Henderson:
#
# You searched for "Skylar Mays"
# 1 result found.
# Skylar Mays
# Results for Skylar Mays:
#
# You searched for "Justin Minaya"
# 1 result found.
# Justin Holiday
# Results for Justin Holiday:
#
# You searched for "Taze Moore"
# 11 results found.
# You searched for "Kris Murray"
# 5 results found.
# You searched for "Duop Reath"
# 0 results found.
# You searched for "Rayan Rupert"
# 0 results found.
# You searched for "Shaedon Sharpe"
# 0 results found.
# You searched for "Anfernee Simons"
# 1 result found.
# Anfernee Simons
# Results for Anfernee Simons:
#
# You searched for "Matisse Thybulle"
# 1 result found.
# Matisse Thybulle
# Results for Matisse Thybulle:
#
# You searched for "Ish Wainright"
# 0 results found.
# You searched for "Jabari Walker"
# 2 results found.
# You searched for "Robert Williams"
# 7 results found.
# Statistics saved for POR
# You searched for "Harrison Barnes"
# 3 results found.
# You searched for "Chris Duarte"
# 7 results found.
# You searched for "Kessler Edwards"
# 1 result found.
# Corsley Edwards
# Results for Corsley Edwards:
#
# You searched for "Keon Ellis"
# 12 results found.
# You searched for "Jordan Ford"
# 12 results found.
# You searched for "De'Aaron Fox"
# 1 result found.
# De'Aaron Fox
# Results for De'Aaron Fox:
#
# You searched for "Kevin Huerter"
# 5 results found.
# You searched for "Colby Jones"
# 13 results found.
# You searched for "Mason Jones"
# 18 results found.
# You searched for "Alex Len"
# 7 results found.
# You searched for "Trey Lyles"
# 5 results found.
# You searched for "JaVale McGee"
# 1 result found.
# JaVale McGee
# Results for JaVale McGee:
#
# You searched for "Davion Mitchell"
# 0 results found.
# You searched for "Malik Monk"
# 5 results found.
# You searched for "Keegan Murray"
# 1 result found.
# Ken Murray
# Results for Ken Murray:
#
# You searched for "Filip Petrusev"
# 0 results found.
# You searched for "Domantas Sabonis"
# 1 result found.
# Domantas Sabonis
# Results for Domantas Sabonis:
#
# You searched for "Jalen Slawson"
# 3 results found.
# You searched for "Juan Toscano-Anderson"
# 1 result found.
# Juan Toscano-Anderson
# Results for Juan Toscano-Anderson:
#
# You searched for "Sasha Vezenkov"
# 0 results found.
# Statistics saved for SAC
# You searched for "Dominick Barlow"
# 0 results found.
# You searched for "Charles Bassey"
# 6 results found.
# You searched for "Jamaree Bouyea"
# 0 results found.
# You searched for "Malaki Branham"
# 0 results found.
# You searched for "Julian Champagnie"
# 0 results found.
# You searched for "Sidy Cissoko"
# 0 results found.
# You searched for "Zach Collins"
# 9 results found.
# You searched for "Mamadi Diakite"
# 1 result found.
# Mamadi Diakite
# Results for Mamadi Diakite:
#
# You searched for "David Duke Jr."
# 0 results found.
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "RaiQuan Gray"
# 0 results found.
# You searched for "Keldon Johnson"
# 12 results found.
# You searched for "Tre Jones"
# 25 results found.
# You searched for "Sandro Mamukelashvili"
# 0 results found.
# You searched for "Doug McDermott"
# 2 results found.
# You searched for "Cedi Osman"
# 1 result found.
# Cedi Osman
# Results for Cedi Osman:
#
# You searched for "Jeremy Sochan"
# 1 result found.
# Jeremy Evans
# Results for Jeremy Evans:
#
# You searched for "Devin Vassell"
# 1 result found.
# Devin Vassell
# Results for Devin Vassell:
#
# You searched for "Victor Wembanyama"
# 0 results found.
# You searched for "Blake Wesley"
# 1 result found.
# Walt Wesley
# Results for Walt Wesley:
#
# Statistics saved for SAS
# You searched for "Precious Achiuwa"
# 1 result found.
# Precious Achiuwa
# Results for Precious Achiuwa:
#
# You searched for "Ochai Agbaji"
# 0 results found.
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Scottie Barnes"
# 0 results found.
# You searched for "RJ Barrett"
# 7 results found.
# You searched for "Chris Boucher"
# 5 results found.
# You searched for "Bruce Brown"
# 16 results found.
# You searched for "D.J. Carton"
# 6 results found.
# You searched for "Gradey Dick"
# 0 results found.
# You searched for "Malachi Flynn"
# 1 result found.
# Malachi Flynn
# Results for Malachi Flynn:
#
# You searched for "Javon Freeman-Liberty"
# 0 results found.
# You searched for "Mouhamadou Gueye"
# 0 results found.
# You searched for "Ron Harper Jr."
# 1 result found.
# Ron Harper
# Results for Ron Harper:
#
# You searched for "Kira Lewis Jr."
# 1 result found.
# Kira Lewis
# Results for Kira Lewis:
#
# You searched for "Jalen McDaniels"
# 4 results found.
# You searched for "Markquis Nowell"
# 0 results found.
# You searched for "Jordan Nwora"
# 6 results found.
# You searched for "Kelly Olynyk"
# 1 result found.
# Kelly Olynyk
# Results for Kelly Olynyk:
#
# You searched for "Jakob Poeltl"
# 1 result found.
# Jakob Poeltl
# Results for Jakob Poeltl:
#
# You searched for "Jontay Porter"
# 1 result found.
# Otto Porter
# Results for Otto Porter:
#
# You searched for "Otto Porter Jr."
# 1 result found.
# Otto Porter
# Results for Otto Porter:
#
# You searched for "Immanuel Quickley"
# 1 result found.
# Immanuel Quickley
# Results for Immanuel Quickley:
#
# You searched for "Jahmi'us Ramsey"
# 1 result found.
# Jahmi'us Ramsey
# Results for Jahmi'us Ramsey:
#
# You searched for "Dennis Schroder"
# 1 result found.
# Dennis Schroder
# Results for Dennis Schroder:
#
# You searched for "Pascal Siakam"
# 1 result found.
# Pascal Siakam
# Results for Pascal Siakam:
#
# You searched for "Kobi Simmons"
# 4 results found.
# You searched for "Garrett Temple"
# 1 result found.
# Garrett Temple
# Results for Garrett Temple:
#
# You searched for "Gary Trent Jr."
# 2 results found.
# You searched for "Malik Williams"
# 38 results found.
# You searched for "Thaddeus Young"
# 1 result found.
# Thaddeus Young
# Results for Thaddeus Young:
#
# Statistics saved for TOR
# You searched for "Ochai Agbaji"
# 0 results found.
# You searched for "Darius Bazley"
# 3 results found.
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "John Collins"
# 17 results found.
# You searched for "Kris Dunn"
# 6 results found.
# You searched for "Simone Fontecchio"
# 0 results found.
# You searched for "Keyonte George"
# 0 results found.
# You searched for "Taylor Hendricks"
# 0 results found.
# You searched for "Talen Horton-Tucker"
# 1 result found.
# Talen Horton-Tucker
# Results for Talen Horton-Tucker:
#
# You searched for "Johnny Juzang"
# 6 results found.
# You searched for "Walker Kessler"
# 3 results found.
# You searched for "Kira Lewis Jr."
# 1 result found.
# Kira Lewis
# Results for Kira Lewis:
#
# You searched for "Kenneth Lofton Jr."
# 0 results found.
# You searched for "Lauri Markkanen"
# 1 result found.
# Lauri Markkanen
# Results for Lauri Markkanen:
#
# You searched for "Kelly Olynyk"
# 1 result found.
# Kelly Olynyk
# Results for Kelly Olynyk:
#
# You searched for "Micah Potter"
# 1 result found.
# Michael Porter
# Results for Michael Porter:
#
# You searched for "Jason Preston"
# 1 result found.
# Jason Lawson
# Results for Jason Lawson:
#
# You searched for "Luka Samanic"
# 1 result found.
# Luka Samanic
# Results for Luka Samanic:
#
# You searched for "Brice Sensabaugh"
# 0 results found.
# You searched for "Collin Sexton"
# 1 result found.
# Collin Sexton
# Results for Collin Sexton:
#
# You searched for "Omer Yurtseven"
# 1 result found.
# Omer Yurtseven
# Results for Omer Yurtseven:
#
# Statistics saved for UTA
# You searched for "Deni Avdija"
# 1 result found.
# Deni Avdija
# Results for Deni Avdija:
#
# You searched for "Marvin Bagley III"
# 1 result found.
# Marvin Bagley
# Results for Marvin Bagley:
#
# You searched for "Patrick Baldwin Jr."
# 0 results found.
# You searched for "Jules Bernard"
# 0 results found.
# You searched for "Jared Butler"
# 9 results found.
# You searched for "Justin Champagnie"
# 0 results found.
# You searched for "Bilal Coulibaly"
# 0 results found.
# You searched for "Johnny Davis"
# 13 results found.
# You searched for "Hamidou Diallo"
# 1 result found.
# Hamidou Diallo
# Results for Hamidou Diallo:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Danilo Gallinari"
# 1 result found.
# Danilo Gallinari
# Results for Danilo Gallinari:
#
# You searched for "Anthony Gill"
# 5 results found.
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Trey Jemison"
# 1 result found.
# Trey Johnson
# Results for Trey Johnson:
#
# You searched for "Tyus Jones"
# 17 results found.
# You searched for "Corey Kispert"
# 0 results found.
# You searched for "Kyle Kuzma"
# 3 results found.
# You searched for "Mike Muscala"
# 2 results found.
# You searched for "Eugene Omoruyi"
# 0 results found.
# You searched for "Jordan Poole"
# 9 results found.
# You searched for "Ryan Rollins"
# 6 results found.
# You searched for "Landry Shamet"
# 1 result found.
# Landry Shamet
# Results for Landry Shamet:
#
# You searched for "Tristan Vukcevic"
# 0 results found.
# You searched for "Delon Wright"
# 4 results found.
# Statistics saved for WAS

# %%
import pandas as pd
from bs4 import BeautifulSoup
from request_utils import get_wrapper

# Function to get the schedule and process it
def get_schedule(season, playoffs=False):
    months = ['October', 'November', 'December', 'January', 'February', 'March',
              'April', 'May', 'June']
    if season == 2023:
        months = ['October-2022', 'November', 'December', 'January', 'February', 'March',
                  'April', 'May', 'June']
    df = pd.DataFrame()
    for month in months:
        url = f'https://www.basketball-reference.com/leagues/NBA_{season}_games-{month.lower()}.html'
        r = get_wrapper(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            table = soup.find('table', attrs={'id': 'schedule'})
            if table:
                month_df = pd.read_html(str(table))[0]
                df = pd.concat([df, month_df])

    df = df.reset_index(drop=True)

    # Drop unnecessary columns dynamically based on the actual column names
    cols_to_remove = ['Start (ET)', 'Unnamed: 6', 'Unnamed: 7', 'Attend.', 'LOG', 'Arena', 'Notes']
    df = df.drop([col for col in cols_to_remove if col in df.columns], axis=1)
    
    # Rename the columns based on the remaining columns
    df.columns = ['DATE', 'VISITOR', 'VISITOR_PTS', 'HOME', 'HOME_PTS']

    df['DATE'] = pd.to_datetime(df['DATE'])
    
    return df

# Function to create match files for each team
def create_team_matches_file(season):
    schedule = get_schedule(season)
    
    nba_teams_map = {
        "Atlanta Hawks": "team1",
        "Boston Celtics": "team2",
        "Brooklyn Nets": "team3",
        "Charlotte Hornets": "team4",
        "Chicago Bulls": "team5",
        "Cleveland Cavaliers": "team6",
        "Dallas Mavericks": "team7",
        "Denver Nuggets" : "team8",
        "Detroit Pistons": "team9",
        "Golden State Warriors": "team10",
        "Houston Rockets": "team11",
        "Indiana Pacers": "team12",
        "Los Angeles Clippers": "team13",
        "Los Angeles Lakers": "team14",
        "Memphis Grizzlies": "team15",
        "Miami Heat": "team16",
        "Milwaukee Bucks": "team17",
        "Minnesota Timberwolves": "team18",
        "New Orleans Pelicans": "team19",
        "New York Knicks": "team20",
        "Oklahoma City Thunder": "team21",
        "Orlando Magic": "team22",
        "Philadelphia 76ers": "team23",
        "Phoenix Suns": "team24",
        "Portland Trail Blazers": "team25",
        "Sacramento Kings": "team26",
        "San Antonio Spurs": "team27",
        "Toronto Raptors": "team28",
        "Utah Jazz": "team29",
        "Washington Wizards": "team30"    
    }
    
    for team_name, team_id in nba_teams_map.items():
        team_schedule = schedule[(schedule['HOME'] == team_name) | (schedule['VISITOR'] == team_name)]
        matches = []
        match_id_counter = int(team_id.replace("team", "")) * 1000
        
        for idx, row in team_schedule.iterrows():
            if row['HOME'] == team_name:
                team1_id = team_id
                team2_id = nba_teams_map.get(row['VISITOR'])
                score_team1 = row['HOME_PTS']
                score_team2 = row['VISITOR_PTS']
            else:
                team1_id = team_id
                team2_id = nba_teams_map.get(row['HOME'])
                score_team1 = row['VISITOR_PTS']
                score_team2 = row['HOME_PTS']

            match_entry = {
                "_id": f"match{match_id_counter}",
                "team1_id": team1_id,
                "team2_id": team2_id,
                "score_team1": score_team1,
                "score_team2": score_team2,
                "match_date": row['DATE'].strftime('%Y-%m-%d')
            }
            matches.append(match_entry)
            match_id_counter += 1
        
        output_filename = f"{team_id}_matches_{season}.json"
        with open(output_filename, 'w') as outfile:
            json.dump(matches, outfile, indent=2)
        
        print(f"Saved matches for {team_name} to {output_filename}")

# Run the function to create match files for the 2023-24 season
create_team_matches_file(2024)  # for 2023-24 season
# Out:
# Saved matches for Atlanta Hawks to team1_matches_2024.json
# Saved matches for Boston Celtics to team2_matches_2024.json
# Saved matches for Brooklyn Nets to team3_matches_2024.json
# Saved matches for Charlotte Hornets to team4_matches_2024.json
# Saved matches for Chicago Bulls to team5_matches_2024.json
# Saved matches for Cleveland Cavaliers to team6_matches_2024.json
# Saved matches for Dallas Mavericks to team7_matches_2024.json
# Saved matches for Denver Nuggets to team8_matches_2024.json
# Saved matches for Detroit Pistons to team9_matches_2024.json
# Saved matches for Golden State Warriors to team10_matches_2024.json
# Saved matches for Houston Rockets to team11_matches_2024.json
# Saved matches for Indiana Pacers to team12_matches_2024.json
# Saved matches for Los Angeles Clippers to team13_matches_2024.json
# Saved matches for Los Angeles Lakers to team14_matches_2024.json
# Saved matches for Memphis Grizzlies to team15_matches_2024.json
# Saved matches for Miami Heat to team16_matches_2024.json
# Saved matches for Milwaukee Bucks to team17_matches_2024.json
# Saved matches for Minnesota Timberwolves to team18_matches_2024.json
# Saved matches for New Orleans Pelicans to team19_matches_2024.json
# Saved matches for New York Knicks to team20_matches_2024.json
# Saved matches for Oklahoma City Thunder to team21_matches_2024.json
# Saved matches for Orlando Magic to team22_matches_2024.json
# Saved matches for Philadelphia 76ers to team23_matches_2024.json
# Saved matches for Phoenix Suns to team24_matches_2024.json
# Saved matches for Portland Trail Blazers to team25_matches_2024.json
# Saved matches for Sacramento Kings to team26_matches_2024.json
# Saved matches for San Antonio Spurs to team27_matches_2024.json
# Saved matches for Toronto Raptors to team28_matches_2024.json
# Saved matches for Utah Jazz to team29_matches_2024.json
# Saved matches for Washington Wizards to team30_matches_2024.json
